# %% [markdown]
# <a href="https://colab.research.google.com/github/alecq26/Data-science-/blob/main/Alec_Quere_Stats_22_Lab_6_Cereal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import urllib.request

# %%
urllib.request.urlretrieve('https://raw.githubusercontent.com/williamedwardhahn/Probability_Statistics/main/cereal_data.csv','cereal_data.csv')
# Out:
# ('cereal_data.csv', <http.client.HTTPMessage at 0x7f9ab149f310>)

# %% [markdown]
# This imports the url to put it in colab

# %%
cereal_data = pd.read_csv('cereal_data.csv')

# %% [markdown]
# This imports the data

# %% [markdown]
# Name: Name of cereal
#
# mfr: Manufacturer of cereal
#
#     A = American Home Food Products
#
#     G = General Mills
#
#     K = Kelloggs
#
#     N = Nabisco
#
#     P = Post
#
#     Q = Quaker Oats
#
#     R = Ralston Purina
#
# type:
#
#     cold
#
#     hot
#
# calories: calories per serving
#
# protein: grams of protein
#
# fat: grams of fat
#
# sodium: milligrams of sodium
#
# fiber: grams of dietary fiber
#
# carbo: grams of complex carbohydrates
#
# sugars: grams of sugars
#
# potass: milligrams of potassium
#
# vitamins: vitamins and minerals - 0, 25, or 100,
# indicating the typical percentage of FDA recommended
#
# shelf: display shelf (1, 2, or 3, counting from the floor)
#
# weight: weight in ounces of one serving
#
# cups: number of cups in one serving
#
# rating: a rating of the cereals

# %% [markdown]
# This asigns the data to a leter

# %%
cereal_data
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %% [markdown]
# This gives all the info on the cereal

# %%
cereal_data["sugars"].mean()
# Out:
# 6.922077922077922

# %% [markdown]
# This is the average amount of sugar between the cereals

# %%
cereal_data[["calories", "sugars"]].mean()
# Out:
# calories    106.883117
# sugars        6.922078
# dtype: float64

# %% [markdown]
# This is the average calories and sugar between the cereals

# %%
cereal_data.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %% [markdown]
# This is another graph of data between the cereals

# %%
cereal_data[["calories", "sugars"]]
# Out:
#     calories  sugars
# 0         70       6
# 1        120       8
# 2         70       5
# 3         50       0
# 4        110       8
# ..       ...     ...
# 72       110       3
# 73       110      12
# 74       100       3
# 75       100       3
# 76       110       8
#
# [77 rows x 2 columns]

# %% [markdown]
# This is a graoh of calories and sugar

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["calories"]],'.')

# %% [markdown]
# This plots the graph of the info

# %%
plt.plot(cereal_data[["fat"]],cereal_data[["calories"]],'.')

# %% [markdown]
# This plots the graph of fat and calories

# %%
plt.plot(cereal_data[["fat"]],cereal_data[["calories"]],'.')

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["carbo"]],'.')

# %% [markdown]
# This plots the graph of carbs and sugar

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["vitamins"]],'.')

# %%
X = cereal_data[["sugars"]]
Y = cereal_data[["calories"]]

# %% [markdown]
# This makes x = sugar and y = calories

# %%
from sklearn.linear_model import LinearRegression
linear_regressor = LinearRegression()

# %% [markdown]
# This sets up a linear regretion

# %%
linear_regressor.fit(X, Y)
Y_pred = linear_regressor.predict(X)

# %% [markdown]
# This puts the linear regretion data in from x and y

# %%
plt.plot(X, Y,'.')
plt.plot(X, Y_pred, color='red')
plt.show()

# %% [markdown]
# This is the linear regretion of the data x and y

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,10,50)

# %% [markdown]
# This puts the data at 10 noise and to 50

# %%
noise = 10 * np.random.randn(50,)

# %%
y = 3 * x + 7 + noise

# %% [markdown]
# This adjust the noise

# %%
plt.plot(x,y,'.');

# %% [markdown]
# This plots the 50 random data points

# %%
m_guess = 1
b_guess = 1

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

# %% [markdown]
# This plots two different data sets

# %%
m_guess = 5
b_guess = 15

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

# %%
m_guess = 3
b_guess = 7

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

# %%
loss = np.sum((y_guess - y)**2)

# %% [markdown]
# This sums up all the data from the loss

# %%
loss
# Out:
# 4607.743814119069

# %% [markdown]
# This is all the dats combine loss

# %%
for m_guess in np.linspace(-10,10,10):
    for b_guess in np.linspace(-10,10,10):
        
        y_guess = m_guess * x + b_guess

        plt.plot(x,y_guess,'r.');
        plt.plot(x,y,'g.');
        plt.show()

        loss = np.sum((y_guess - y)**2)

        print(loss,m_guess,b_guess)
# Out:
# 422737.14879238734 -10.0 -10.0
# 404597.02970905765 -10.0 -7.777777777777778
# 386950.7377862217 -10.0 -5.555555555555555
# 369798.2730238796 -10.0 -3.333333333333333
# 353139.6354220314 -10.0 -1.1111111111111107
# 336974.8249806769 -10.0 1.1111111111111107
# 321303.84169981634 -10.0 3.333333333333334
# 306126.6855794495 -10.0 5.555555555555557
# 291443.3566195766 -10.0 7.777777777777779
# 277253.85482019745 -10.0 10.0
# 313622.6247503148 -7.777777777777778 -10.0
# 297951.64146945416 -7.777777777777778 -7.777777777777778
# 282774.48534908745 -7.777777777777778 -5.555555555555555
# 268091.15638921445 -7.777777777777778 -3.333333333333333
# 253901.65458983535 -7.777777777777778 -1.1111111111111107
# 240205.97995095002 -7.777777777777778 1.1111111111111107
# 227004.13247255856 -7.777777777777778 3.333333333333334
# 214296.1121546609 -7.777777777777778 5.555555555555557
# 202081.91899725707 -7.777777777777778 7.777777777777779
# 190361.55300034708 -7.777777777777778 10.0
# ...

# %% [markdown]
# This is the data from the arrays plotted

# %%
best_loss = 100000
best_m = 0
best_b = 0 

for m_guess in np.linspace(-10,10,20):
    for b_guess in np.linspace(-10,10,20):
        
        y_guess = m_guess * x + b_guess

        loss = np.sum((y_guess - y)**2)

        if loss < best_loss:
            
            best_loss = loss
            best_m = m_guess
            best_b = b_guess 

            plt.plot(x,y_guess,'r.');
            plt.plot(x,y,'g.');
            plt.show()

            print(loss,m_guess,b_guess)
# Out:
# 98403.36479385543 -4.736842105263158 10.0
# 95502.82867047141 -3.6842105263157894 3.6842105263157894
# 91613.12621764147 -3.6842105263157894 4.7368421052631575
# 87834.22708891126 -3.6842105263157894 5.789473684210526
# 84166.13128428075 -3.6842105263157894 6.842105263157894
# 80608.83880375 -3.6842105263157894 7.894736842105264
# 77162.34964731896 -3.6842105263157894 8.94736842105263
# 73826.66381498761 -3.6842105263157894 10.0
# 71333.16031074546 -2.6315789473684212 3.6842105263157894
# 67997.47447841412 -2.6315789473684212 4.7368421052631575
# 64772.59197018252 -2.6315789473684212 5.789473684210526
# 61658.51278605063 -2.6315789473684212 6.842105263157894
# 58655.23692601847 -2.6315789473684212 7.894736842105264
# 55762.76439008604 -2.6315789473684212 8.94736842105263
# 52981.09517825332 -2.6315789473684212 10.0
# 50894.624293153014 -1.578947368421053 3.6842105263157894
# 48112.9550813203 -1.578947368421053 4.7368421052631575
# ...

# %% [markdown]
# sets the loss higher and plots the data
