# %% [markdown]
# <a href="https://colab.research.google.com/github/alecq26/Data-science-/blob/main/Lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt 
from skimage.io import imread

# %%
url = 'https://www.motortrend.com/uploads/sites/5/2018/11/2019-Bentley-Continental-GT-Convertible-side.jpg?fit=around%7C875:492'

# %%
im = imread(url)

# %%
plt.figure(figsize=(20,10))
plt.imshow(im);
plt.axis('off');
